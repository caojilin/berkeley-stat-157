# %%
# %matplotlib inline
import mxnet as mx
from mxnet import nd, autograd
from matplotlib import pyplot as plt

M = nd.random.normal(shape=(4,4))
print('A single matrix', M)
for i in range(100):
    M = nd.dot(M, nd.random.normal(shape=(4,4)))

print('After multiplying 100 matrices', M)
# Out:
# A single matrix
# [[ 1.1630787   0.4838046   0.29956347  0.15302546]
#  [-1.1688148   1.5580711  -0.5459446  -2.3556297 ]
#  [ 0.5414402   2.6785066   1.2546344  -0.54877394]
#  [-0.68106437 -0.13531584  0.37723127  0.41016445]]
# <NDArray 4x4 @cpu(0)>
# After multiplying 100 matrices
# [[-4.3622871e+23  2.7321716e+23  2.7285031e+22  1.4412828e+23]
#  [-2.6033558e+24  1.6305246e+24  1.6283332e+23  8.6013875e+23]
#  [-2.0975528e+24  1.3137317e+24  1.3119668e+23  6.9302328e+23]
#  [ 6.1648658e+23 -3.8611568e+23 -3.8559680e+22 -2.0368479e+23]]
# <NDArray 4x4 @cpu(0)>

# %%
x = nd.arange(-8.0, 8.0, 0.1)
x.attach_grad()
with autograd.record():
    y = x.sigmoid()
y.backward()

plt.figure(figsize=(8, 4))
plt.plot(x.asnumpy(), y.asnumpy())
plt.plot(x.asnumpy(), x.grad.asnumpy())
plt.legend(['sigmoid', 'gradient'])
plt.show()
